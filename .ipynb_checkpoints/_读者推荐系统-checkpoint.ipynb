# %%
import csv 
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# csv_file = csv.reader(open('a.txt','r',encoding='utf-8'))
# a=[]

# %%
# for i in csv_file:
#     a.append(i)
# b = pd.DataFrame(a)

# %%
# b.to_csv('target.csv')

# %%
c = pd.read_csv('target.csv',header=1, keep_default_na=0,index_col=0)
c.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              读者条码   姓名 读者级别  单位代码      单位        条形码          读者条码.1  \
# 0
# 1  20131201021010  *思其   学生    15     保险系  200541770  20131201021010
# 2  20131201021010  *思其   学生    15     保险系  200541770  20131201021010
# 3  20121205021068  *欢欢   学生    16     会计系  200592885  20121205021068
# 4  20121205021068  *欢欢   学生    16     会计系  200592885  20121205021068
# 5     20110912043  *欣瑜   学生    38  国际教育学院  200346287     20110912043
#
#                   处理时间 操作类型   主键码           题名        出版者       责任者  \
# 0
# 1  2016/12/27 17:25:48    J  9360  国企改革中的难点与对策      新华出版社       齐勇著
# 2    2017/1/3 14:26:29    H  9360  国企改革中的难点与对策      新华出版社       齐勇著
# 3    2013/3/5 14:14:35    H  8143     企业会计核算精要    中国计量出版社    陈新环等编著
# ...

# %%
c.head()
# Out:
#              读者条码   姓名 读者级别  单位代码      单位        条形码          读者条码.1  \
# 0
# 1  20131201021010  *思其   学生    15     保险系  200541770  20131201021010
# 2  20131201021010  *思其   学生    15     保险系  200541770  20131201021010
# 3  20121205021068  *欢欢   学生    16     会计系  200592885  20121205021068
# 4  20121205021068  *欢欢   学生    16     会计系  200592885  20121205021068
# 5     20110912043  *欣瑜   学生    38  国际教育学院  200346287     20110912043
#
#                   处理时间 操作类型   主键码           题名        出版者       责任者  \
# 0
# 1  2016/12/27 17:25:48    J  9360  国企改革中的难点与对策      新华出版社       齐勇著
# 2    2017/1/3 14:26:29    H  9360  国企改革中的难点与对策      新华出版社       齐勇著
# 3    2013/3/5 14:14:35    H  8143     企业会计核算精要    中国计量出版社    陈新环等编著
# 4   2013/1/17 10:53:04    J  8143     企业会计核算精要    中国计量出版社    陈新环等编著
# 5  2013/12/12 11:51:29    J  1344  世界经济政治与国际关系  北京广播学院出版社  杨伟芬、李涛源著
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17
# 0
# 1
# 2
# 3
# 4
# 5

# %%
c.describe(include='all')
# Out:
#                 读者条码      姓名    读者级别           单位代码      单位          条形码  \
# count   3.748220e+05  374822  374822  374822.000000  374822     374822.0
# unique           NaN    7929       6            NaN      97      76420.0
# top              NaN      *静      学生            NaN     金融系  200826335.0
# freq             NaN    2850  335560            NaN   56487        244.0
# mean    1.508459e+13     NaN     NaN      26.460773     NaN          NaN
# std     8.691563e+12     NaN     NaN      42.015644     NaN          NaN
# min     1.000000e+00     NaN     NaN       1.000000     NaN          NaN
# 25%     2.016126e+12     NaN     NaN      15.000000     NaN          NaN
# 50%     2.013121e+13     NaN     NaN      17.000000     NaN          NaN
# 75%     2.014121e+13     NaN     NaN      20.000000     NaN          NaN
# max     2.018221e+13     NaN     NaN     543.000000     NaN          NaN
#
#               读者条码.1                处理时间    操作类型            主键码          题名  \
# ...

# %%
c.shape
# Out:
# (374822, 17)

# %%
c.to_csv('complet.csv')

# %%
c.columns
# Out:
# Index(['读者条码', '姓名', '读者级别', '单位代码', '单位', '条形码', '读者条码.1', '处理时间', '操作类型',
#        '主键码', '题名', '出版者', '责任者', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17'],
#       dtype='object')

# %%
c.duplicated().sum()
# Out:
# 32

# %%
c.iloc[141]
# Out:
# 读者条码                       2009002
# 姓名                             *卫民
# 读者级别                            教师
# 单位代码                             1
# 单位                          河北金融学院
# 条形码                      200420231
# 读者条码.1                     2009002
# 处理时间           2016/12/19 08:00:48
# 操作类型                             J
# 主键码                           4470
# 题名                      从计划经济到市场经济
# 出版者                      中国财政经济出版社
# 责任者                       盛洪、张宇燕主编
# Unnamed: 14
# Unnamed: 15
# Unnamed: 16
# Unnamed: 17
# Name: 142, dtype: object

# %%
del c['Unnamed: 14']
del c['Unnamed: 15']
del c['Unnamed: 16']
del c['Unnamed: 17']

# %%
del c['读者条码.1']

# %%
c
# Out:
#                   读者条码   姓名 读者级别  单位代码      单位        条形码  \
# 0
# 1       20131201021010  *思其   学生    15     保险系  200541770
# 2       20131201021010  *思其   学生    15     保险系  200541770
# 3       20121205021068  *欢欢   学生    16     会计系  200592885
# 4       20121205021068  *欢欢   学生    16     会计系  200592885
# 5          20110912043  *欣瑜   学生    38  国际教育学院  200346287
# ...                ...  ...  ...   ...     ...        ...
# 374818  20120203022053  *凯敏   学生    20     管理系  207848105
# 374819  20131203021037   *蕾   学生    20     管理系  207848105
# 374820  20131204011057   *悦   学生    38  国际教育学院  207848105
# 374821  20131205011011  *丽婷   学生    16     会计系  207848105
# 374822  20131205011011  *丽婷   学生    16     会计系  207848105
#
#                        处理时间 操作类型     主键码           题名        出版者       责任者
# 0
# 1       2016/12/27 17:25:48    J    9360  国企改革中的难点与对策      新华出版社       齐勇著
# 2         2017/1/3 14:26:29    H    9360  国企改革中的难点与对策      新华出版社       齐勇著
# ...

# %%
c.iloc[141]
# Out:
# 读者条码                2009002
# 姓名                      *卫民
# 读者级别                     教师
# 单位代码                      1
# 单位                   河北金融学院
# 条形码               200420231
# 处理时间    2016/12/19 08:00:48
# 操作类型                      J
# 主键码                    4470
# 题名               从计划经济到市场经济
# 出版者               中国财政经济出版社
# 责任者                盛洪、张宇燕主编
# Name: 142, dtype: object

# %%
mpl.rcParams['font.sans-serif']=['SimHei'] 
c['姓名'].value_counts().head(5).plot('bar')
plt.title('借阅数量最多的5位读者')
plt.xlabel('读者姓名')
plt.ylabel('借阅数量')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
# Text(0, 0.5, '借阅数量')

# %%
mpl.rcParams['font.sans-serif']=['SimHei'] 
c['单位'].value_counts().head(5).plot('bar')
plt.title('借阅数量最多的5个单位')
plt.xlabel('单位名称')
plt.ylabel('借阅数量')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
# Text(0, 0.5, '借阅数量')

# %%
mpl.rcParams['font.sans-serif']=['SimHei'] 
c['出版者'].value_counts().head(5).plot('bar')
plt.title('被借阅数量最多的5个出版者')
plt.xlabel('出版者名称')
plt.ylabel('借阅数量')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
# Text(0, 0.5, '借阅数量')

# %%
c['读者级别'].value_counts()
# Out:
# 学生      335560
# 教师       33366
# 研究生       5851
# 特殊人员        28
# 校外人员        14
# 大额借书         3
# Name: 读者级别, dtype: int64

# %%
mpl.rcParams['font.sans-serif']=['SimHei'] 
c['读者级别'].value_counts().plot('pie',autopct='%1.1f%%')
plt.title('不同读者身份所占比')
plt.xlabel('读者身份')
plt.ylabel('借阅比例')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='pie')` instead of `Series.plot('pie',)`.
# Text(0, 0.5, '借阅比例')

# %%
mpl.rcParams['font.sans-serif']=['SimHei'] 
c['读者级别'].value_counts().plot('bar')
plt.title('不同读者身份借阅数量')
plt.xlabel('读者身份')
plt.ylabel('借阅比例')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
# Text(0, 0.5, '借阅比例')

# %%
print(123)
# Out:
# 123

# %% [markdown]
# ## 搭建推荐算法模型

# %% [markdown]
# 使用基于图的推荐方法

# %% [markdown]
# step1 将用户借阅数据表示为二分图

# %%
data = pd.DataFrame(columns=['u','p'])
data['u'] = [0,0,0,1,1,1,2,2,3,3,3,4,4]
data['p'] = [1,2,4,1,2,3,3,5,1,4,5,2,6]

# %%
data
# Out:
#     u  p
# 0   0  1
# 1   0  2
# 2   0  4
# 3   1  1
# 4   1  2
# 5   1  3
# 6   2  3
# 7   2  5
# 8   3  1
# 9   3  4
# 10  3  5
# 11  4  2
# 12  4  6

# %%
# 为用户u和书籍p的id添加标识
data['u'] = data['u'].apply(lambda x : 'u'+ str(x))
data['p'] = data['p'].apply(lambda x : 'p'+ str(x))
data
# Out:
#      u   p
# 0   u0  p1
# 1   u0  p2
# 2   u0  p4
# 3   u1  p1
# 4   u1  p2
# 5   u1  p3
# 6   u2  p3
# 7   u2  p5
# 8   u3  p1
# 9   u3  p4
# 10  u3  p5
# 11  u4  p2
# 12  u4  p6

# %%
# 将用户借阅数据表示为二分图
def extra_G(data):
    
    G={}
    # 存储每个用户节点和对应的书籍
    for u, group in data.groupby('u'):
        G[u] = list(group['p'])
    # 存储每个书籍和对应的用户
    for p, group in data.groupby('p'):
        G[p] = list(group['u'])
        
    return G

# %%
G = extra_G(data)
G
# Out:
# {'u0': ['p1', 'p2', 'p4'],
#  'u1': ['p1', 'p2', 'p3'],
#  'u2': ['p3', 'p5'],
#  'u3': ['p1', 'p4', 'p5'],
#  'u4': ['p2', 'p6'],
#  'p1': ['u0', 'u1', 'u3'],
#  'p2': ['u0', 'u1', 'u4'],
#  'p3': ['u1', 'u2'],
#  'p4': ['u0', 'u3'],
#  'p5': ['u2', 'u3'],
#  'p6': ['u4']}

# %% [markdown]
# step2 实现PersonalRank算法，计算用户对于每个书籍的借阅概率

# %%
# 实现PersonalRank算法
def personal_rank(G, root, alpha=0.6, n_iter=10):
    
    # 初始化所有节点的访问概率为0
    rank = {x: 0 for x in G.keys()}
    # 初始化vu节点的访问概率为1
    rank[root]=1
    
    # 迭代n次计算用户对每个节点的访问概率
    for k in range(n_iter):
        # 新建字典保存计算结果
        tmp = {x: 0 for x in G.keys()}
        # 计算每一个节点的被访问概率
        for i in G.keys():
            for j in G[i]:
                tmp[j] += alpha*rank[i] / len(G[i])
        tmp[root] += (1 - alpha)
        # 更新节点访问概率
        rank = tmp
    return rank

# %%
# 算法演示
personal_rank(G, 'u0', alpha=0.6, n_iter=10)
# Out:
# {'u0': 0.47926683040000007,
#  'u1': 0.050640364800000004,
#  'u2': 0.008401271999999998,
#  'u3': 0.060770752000000004,
#  'u4': 0.0281882624,
#  'p1': 0.11729185279999998,
#  'p2': 0.11359181439999998,
#  'p3': 0.0121056256,
#  'p4': 0.10744109439999999,
#  'p5': 0.0141285184,
#  'p6': 0.008173612799999999}

# %% [markdown]
# step3 给用户做推荐

# %%
# 为用户各推荐2个地点
def recommend():
    # 新建字典保存结果
    recommend = {}
    for i in range(5):
        # 合成用户id
        u = 'u'+str(i)
        # 计算节点访问概率
        rank = personal_rank(G, u, alpha=0.6, n_iter=10)
        # 形成初步推荐列表
        res = {}
        for key,value in rank.items():
            if (key[0]=='p') and (key not in G[u]):
                res[key] = value
        # 排序并选取前2个地点保存到推荐列表
        recommend[u] = sorted(res.items(), key=lambda x :x[1], reverse=True)[:2]
    return recommend

# %%
recommend()
# Out:
# {'u0': [('p5', 0.0141285184), ('p3', 0.0121056256)],
#  'u1': [('p5', 0.0173775904), ('p4', 0.0162135296)],
#  'u2': [('p1', 0.024533798399999994), ('p2', 0.014214556799999998)],
#  'u3': [('p2', 0.0195607808), ('p3', 0.0176268832)],
#  'u4': [('p1', 0.017649983999999997), ('p4', 0.009497971199999998)]}

# %%
c.head()
# Out:
#              读者条码   姓名 读者级别  单位代码      单位        条形码                 处理时间  \
# 0
# 1  20131201021010  *思其   学生    15     保险系  200541770  2016/12/27 17:25:48
# 2  20131201021010  *思其   学生    15     保险系  200541770    2017/1/3 14:26:29
# 3  20121205021068  *欢欢   学生    16     会计系  200592885    2013/3/5 14:14:35
# 4  20121205021068  *欢欢   学生    16     会计系  200592885   2013/1/17 10:53:04
# 5     20110912043  *欣瑜   学生    38  国际教育学院  200346287  2013/12/12 11:51:29
#
#   操作类型   主键码           题名        出版者       责任者
# 0
# 1    J  9360  国企改革中的难点与对策      新华出版社       齐勇著
# 2    H  9360  国企改革中的难点与对策      新华出版社       齐勇著
# 3    H  8143     企业会计核算精要    中国计量出版社    陈新环等编著
# 4    J  8143     企业会计核算精要    中国计量出版社    陈新环等编著
# 5    J  1344  世界经济政治与国际关系  北京广播学院出版社  杨伟芬、李涛源著

# %%
c.columns
# Out:
# Index(['读者条码', '姓名', '读者级别', '单位代码', '单位', '条形码', '处理时间', '操作类型', '主键码', '题名',
#        '出版者', '责任者'],
#       dtype='object')

# %%
# c.rename(columns={'读者条码':'user_id','姓名':'user_name','读者级别':'level',
#                   '单位代码':'comyany_code','单位':'company','条形码':'line_code',
#                  '读者条码.1':'user_code','处理时间':'time','操作类型':'operation','主键码':'primary_code',
#                  '题名':'book_name','出版者':'prodect','责任者':'writer'})

# %%
c.columns
# Out:
# Index(['读者条码', '姓名', '读者级别', '单位代码', '单位', '条形码', '处理时间', '操作类型', '主键码', '题名',
#        '出版者', '责任者'],
#       dtype='object')

# %%
del c['姓名']
del c['读者级别']
del c['单位代码']
del c['单位']
del c['条形码']
del c['处理时间']
del c['操作类型']
del c['主键码']
del c['出版者']
del c['责任者']
c
# Out:
#                   读者条码           题名
# 0
# 1       20131201021010  国企改革中的难点与对策
# 2       20131201021010  国企改革中的难点与对策
# 3       20121205021068     企业会计核算精要
# 4       20121205021068     企业会计核算精要
# 5          20110912043  世界经济政治与国际关系
# ...                ...          ...
# 374818  20120203022053         曾许诺*
# 374819  20131203021037         曾许诺*
# 374820  20131204011057         曾许诺*
# 374821  20131205011011         曾许诺*
# 374822  20131205011011         曾许诺*
#
# [374822 rows x 2 columns]

# %%
c['index']=c.index

# %%
c
# Out:
#                   读者条码           题名   index
# 0
# 1       20131201021010  国企改革中的难点与对策       1
# 2       20131201021010  国企改革中的难点与对策       2
# 3       20121205021068     企业会计核算精要       3
# 4       20121205021068     企业会计核算精要       4
# 5          20110912043  世界经济政治与国际关系       5
# ...                ...          ...     ...
# 374818  20120203022053         曾许诺*  374818
# 374819  20131203021037         曾许诺*  374819
# 374820  20131204011057         曾许诺*  374820
# 374821  20131205011011         曾许诺*  374821
# 374822  20131205011011         曾许诺*  374822
#
# [374822 rows x 3 columns]

# %%
c['index'] = c['index'].apply(lambda x : 'u'+ str(x))

# %%
c

# %%
# 将用户借阅数据表示为二分图
def extra_G(data):
    
    G={}
    # 存储每个用户节点和对应的书籍
    for u, group in data.groupby('index'):
        G[u] = list(group['题名'])
    # 存储每个书籍和对应的用户
    for p, group in data.groupby('题名'):
        G[p] = list(group['index'])
        
    return G

# %%
G = extra_G(c)

# %%
G
# Out:
# {'u1': ['国企改革中的难点与对策'],
#  'u10': ['企业财务会计'],
#  'u100': ['经济思想史话'],
#  'u1000': ['国营农业企业财务会计'],
#  'u10000': ['国营农业企业财务会计'],
#  'u100000': ['2013年考研英语阅读理解高分强化训练100篇'],
#  'u100001': ['2013年考研英语阅读理解高分强化训练100篇'],
#  'u100002': ['2013年考研英语阅读理解高分强化训练100篇'],
#  'u100003': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100004': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100005': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100006': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100007': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100008': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100009': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u10001': ['国营农业企业财务会计'],
#  'u100010': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100011': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100012': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100013': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100014': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100015': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100016': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
#  'u100017': ['计量经济学同步辅导与习题全解:科学社·庞皓·第二版'],
# ...

# %%
G['u43221']
# Out:
# ['激励员工有绝招']

# %%
type(G)
# Out:
# dict

# %%
G['u1653']
# Out:
# ['国营农业企业财务会计']

# %% [markdown]
# step2 实现PersonalRank算法，计算用户对于每个书籍的借阅概率

# %%
# 实现PersonalRank算法
def personal_rank(G, root, alpha=0.6, n_iter=10):
    
    # 初始化所有节点的访问概率为0
    rank = {x: 0 for x in G.keys()}
    # 初始化vu节点的访问概率为1
    rank[root]=1
    
    # 迭代n次计算用户对每个节点的访问概率
    for k in range(n_iter):
        # 新建字典保存计算结果
        tmp = {x: 0 for x in G.keys()}
        # 计算每一个节点的被访问概率
        for i in G.keys():
            for j in G[i]:
                tmp[j] += alpha*rank[i] / len(G[i])
        tmp[root] += (1 - alpha)
        # 更新节点访问概率
        rank = tmp
    return rank

# %%
# 算法演示
personal_rank(G, 'u100890', alpha=0.6, n_iter=10)
# Out:
# {'u1': 0.0,
#  'u10': 0.0,
#  'u100': 0.0,
#  'u1000': 0.0,
#  'u10000': 0.0,
#  'u100000': 0.0,
#  'u100001': 0.0,
#  'u100002': 0.0,
#  'u100003': 0.0,
#  'u100004': 0.0,
#  'u100005': 0.0,
#  'u100006': 0.0,
#  'u100007': 0.0,
#  'u100008': 0.0,
#  'u100009': 0.0,
#  'u10001': 0.0,
#  'u100010': 0.0,
#  'u100011': 0.0,
#  'u100012': 0.0,
#  'u100013': 0.0,
#  'u100014': 0.0,
#  'u100015': 0.0,
#  'u100016': 0.0,
#  'u100017': 0.0,
#  'u100018': 0.0,
#  'u100019': 0.0,
#  'u10002': 0.0,
#  'u100020': 0.0,
#  'u100021': 0.0,
#  'u100022': 0.0,
#  'u100023': 0.0,
#  'u100024': 0.0,
#  'u100025': 0.0,
#  'u100026': 0.0,
#  'u100027': 0.0,
#  'u100028': 0.0,
#  'u100029': 0.0,
#  'u10003': 0.0,
#  'u100030': 0.0,
#  'u100031': 0.0,
#  'u100032': 0.0,
#  'u100033': 0.0,
#  'u100034': 0.0,
#  'u100035': 0.0,
#  'u100036': 0.0,
#  'u100037': 0.0,
#  'u100038': 0.0,
#  'u100039': 0.0,
#  'u10004': 0.0,
#  'u100040': 0.0,
#  'u100041': 0.0,
#  'u100042': 0.0,
#  'u100043': 0.0,
# ...

# %% [markdown]
# step3 给用户做推荐

# %%
# 为用户各推荐2个地点
def recommend():
    # 新建字典保存结果
    recommend = {}
    for i in range(10):
        # 合成用户id
        u = 'u'+str(i)
        # 计算节点访问概率
        rank = personal_rank(G, i, alpha=0.6, n_iter=10)
        # 形成初步推荐列表
        res = {}
        for key,value in rank.items():
            if (key[0]=='题名') and (key not in G[u]):
                res[key] = value
        # 排序并选取前2个地点保存到推荐列表
        recommend[u] = sorted(res.items(), key=lambda x :x[1], reverse=True)[:2]
    return recommend

# %%
recommend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-7b578af60541> in <module>
# ----> 1 recommend()
#
# <ipython-input-75-3ae6584104f3> in recommend()
#       7         u = 'u'+str(i)
#       8         # 计算节点访问概率
# ----> 9         rank = personal_rank(G, i, alpha=0.6, n_iter=10)
#      10         # 形成初步推荐列表
#      11         res = {}
#
# <ipython-input-68-bc82a4e0e77b> in personal_rank(G, root, alpha, n_iter)
#      15             for j in G[i]:
#      16                 tmp[j] += alpha*rank[i] / len(G[i])
# ---> 17         tmp[root] += (1 - alpha)
#      18         # 更新节点访问概率
#      19         rank = tmp
#
# KeyError: 0
